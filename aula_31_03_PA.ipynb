# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandesclara1506-png/PA-1F-grupo-A/blob/main/aula_31_03_PA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estrutura de decisão
#
# Escrever um programa que recebe o nome e a idade
# do usuário e verifica se o usuário é criança, adolecente e adulto
#
# <=12 anos é criança
# =< 17 anos é adolecente
# Adulto

# %%
#entrada
nome = str(input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))

#processamento/ saída
if idade <= 12:
  print(f"Oii {nome}, você tem {idade} anos, então você é criança")

elif idade <= 17:
   print(f"Oii {nome}, você tem {idade} anos, então você é adolecente")

else:
 print(f"Oii {nome}, você tem {idade} anos, então você é adulto")
# Out:
# Digite seu nome: clara
# Digite sua idade: 18
# Oii clara, você tem 18 anos, então você é adulto

# %% [markdown]
# Em um jogo, umpersonagem possui uma variável chamada energia.
# O programa deve: Se a energia for maior que 70 - Forte, se a energia estiver entre 30 e 70 - Cansado, se a energia estiver menor que 30 - Fraco

# %%
#entrada
energia = int(input("Digite a energia do personagem: "))

#processamento/ saída
if energia <= 30:
  print("Seu personagem está fraco")

elif energia <= 70:
  print("Seu personagem está cansado")

else:
 print("Seu personagem esta forte")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6859/2899626113.py in <cell line: 0>()
#       1 #entrada
# ----> 2 energia = int(input("Digite a energia do personagem: "))
#       3
#       4 #processamento/ saída
#       5 if energia <= 30:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# Escrever um programa que classifica os tipos de triângulo e se valida é um troângulo

# %%
#entrada
lado1 = float(input("Digite a medida do lado 1: "))
lado2 = float(input("Digite a medida do lado 2: "))
lado3 = float(input("Digite a medida do lado 3: "))

        #Processamento: Condição de existência
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado3 + lado2 > lado1:
            print("A sua figura é um triângulo ")

            #processamneto: tipos
            if lado1==lado2==lado3:
                print("Seu triângulo é um equilátero (todos os lados igual)")

            elif lado1 == lado2 and lado1 == lado3 and lado2 == lado3:
                print("Seu triângulo é um ISÓSCELES (dois lados iguais)")

            else:
                print("Seu triângulo é um ESCALENO (todos os lados diferentes)")

else:
            print("Os valores NÃO formam um triângulo.")
            print("Condição: A soma de dois lados deve ser maior que o terceiro.")
# Out:
# Digite a medida do lado 1: 8
# Digite a medida do lado 2: 9
# Digite a medida do lado 3: 1
# Os valores NÃO formam um triângulo.
# Condição: A soma de dois lados deve ser maior que o terceiro.

# %%
def analisar_triangulo():
    print("--- Verificador de Triângulos ---")

    try:
        # 1. Entrada de dados
        a = float(input("Digite o valor do primeiro lado: "))
        b = float(input("Digite o valor do segundo lado: "))
        c = float(input("Digite o valor do terceiro lado: "))

        # 2. Validação: Condição de existência
        # A soma de dois lados deve ser maior que o terceiro lado
        if (a + b > c) and (a + c > b) and (b + c > a):
            print("\nOs valores formam um triângulo VÁLIDO.")

            # 3. Classificação quanto aos lados
            if a == b == c:
                print("Tipo: Triângulo Equilátero (três lados iguais).")
            elif a == b or a == c or b == c:
                print("Tipo: Triângulo Isósceles (dois lados iguais).")
            else:
                print("Tipo: Triângulo Escaleno (todos os lados diferentes).")
        else:
            print("\nOs valores NÃO formam um triângulo.")
            print("Condição: A soma de dois lados deve ser maior que o terceiro.")
# Out:
# --- Verificador de Triângulos ---
# Digite o valor do primeiro lado: 1
# Digite o valor do segundo lado: 8
# Digite o valor do terceiro lado: 9
#
# Os valores NÃO formam um triângulo.
# Condição: A soma de dois lados deve ser maior que o terceiro.
