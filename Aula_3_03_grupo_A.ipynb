# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandesclara1506-png/PA-1F-grupo-A/blob/main/Aula_3_03_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula de programção e algoritmo
#
# Cálculo da área:
#
# * Entrada
#
# 1- ler do lado 1
#
# 2- ler do lado 2
#
# * processamento
#
# * lado1*lado2
#
# saída- total área
